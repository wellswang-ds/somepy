# %%
# source used: https://towardsdatascience.com/python-for-pdf-ef0fac2808b0
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install tabula-py
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import tabula

# %%
# use tabula to read the table from the file data.pdf into a data frame
# assumes that the file is in the same path as the jupyter notebook
# the entire filepath can also be included

pdf_df = tabula.read_pdf("data.pdf")

# %%
# look at the resulting dataframepdf_df.head()
pdf_df.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
# now it can be easily written back to a csv file
pdf_df.to_csv("data_pdf_to_csv.csv", index = False)

# %%
# !{sys.executable} -m pip install --upgrade pip
# Out:
# ...
#   Found existing installation: pip 10.0.1
#     Uninstalling pip-10.0.1:
#       Successfully uninstalled pip-10.0.1
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.

# %%
# !{sys.executable} -m pip install PyHamcrest

# %%
tabula.read_pdf('C:/Users/kseal/Downloads/BMD.pdf', output_format="json")
# Out:
# [{'extraction_method': 'stream',
#   'top': 0.0,
#   'left': 0.0,
#   'width': 505.19000244140625,
#   'height': 668.6400146484375,
#   'data': [[{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 40.07,
#      'left': 480.96,
#      'width': 24.230010986328125,
#      'height': 3.009999990463257,
#      'text': 'List Price'}],
#    [{'top': 43.19,
#      'left': 93.96,
#      'width': 33.55792999267578,
#      'height': 3.009999990463257,
#      'text': 'Item Number'},
#     {'top': 43.43,
#      'left': 224.52,
#      'width': 22.80999755859375,
#      'height': 3.009999990463257,
#      'text': 'Cameras'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 46.91,
#      'left': 485.52,
# ...

# %%
pdf_bmd.head()
# Out:
#             Unnamed: 0                                         Unnamed: 1  \
# 0          Item Number                                            Cameras
# 1                  NaN                                                NaN
# 2  BMD-CINECAMMICHDMFT                     BLACKMAGIC Micro Cinema Camera
# 3                  NaN  The world’s smallest digital film camera with ...
# 4                  NaN  designed to be operated remotely. Features a r...
#
#   List Price
# 0        NaN
# 1      (GBP)
# 2       £805
# 3        NaN
# 4        NaN

# %%
# using tabula to read the table from a specific page
pdf_sample1 = tabula.read_pdf('E:/All Data/Business Analytics Book idea/pdf/pdfsampleforclass.pdf')

# %%
pdf_sample1
# Out:
#    Notice Date                 Effective                  Received  \
# 0          NaN                      Date                      Date
# 1   06/30/2016  0  8  / 3  1  / 2  0  16  0  7  / 0  1  / 2  0  16
# 2   06/30/2016  0  8  / 3  1  / 2  0  16  0  7  / 0  1  / 2  0  16
# 3   06/30/2016  0  8  / 3  1  / 2  0  16  0  7  / 0  1  / 2  0  16
# 4   06/30/2016  0  8  / 3  1  / 2  0  16  0  7  / 0  1  / 2  0  16
# 5   06/30/2016  0  8  / 3  1  / 2  0  16  0  7  / 0  1  / 2  0  16
# 6   06/30/2016  0  8  / 3  1  / 2  0  16  0  7  / 0  1  / 2  0  16
# 7   06/30/2016  0  8  / 3  1  / 2  0  16  0  7  / 0  1  / 2  0  16
# 8   06/30/2016  0  8  / 3  1  / 2  0  16  0  7  / 0  1  / 2  0  16
# 9   06/30/2016  0  8  / 3  1  / 2  0  16  0  7  / 0  1  / 2  0  16
# 10  06/30/2016  0  8  / 3  1  / 2  0  16  0  7  / 0  1  / 2  0  16
# 11  06/30/2016  0  8  / 3  1  / 2  0  16  0  7  / 0  1  / 2  0  16
# 12  06/30/2016  0  8  / 3  1  / 2  0  16  0  7  / 0  1  / 2  0  16
# ...

# %%
pdf_NZ_water.head(6)
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      1995.0      1996.0      1997.0      1998.0      1999.0      2000.0
# 1         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 6       Year ended June  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 0      2001.0             2002 2003      2004.0      2005.0       2006.0
# 1         NaN  Million cubic metres         NaN         NaN          NaN
#
#    Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14
# 0       2007.0       2008.0       2009.0       2010.0
# 1          NaN          NaN          NaN          NaN
